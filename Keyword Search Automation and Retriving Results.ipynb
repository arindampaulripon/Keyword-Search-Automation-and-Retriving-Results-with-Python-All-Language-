# %%
import requests 
import re
from bs4 import BeautifulSoup 
q = input("Enter keyword here:")
URL = ("https://www.google.com/search?q="+q)

r = requests.get(URL) 

#soup = BeautifulSoup(r.content)
soup = BeautifulSoup(r.content, 'html.parser') 
#print(soup.prettify()) 

#soup = BeautifulSoup(txt,'html.i')
#print("".join(soup.strings))
#url = urllib2.urlopen("https://www.python.org")

    
for node in soup.findAll('h3'):
    print (''.join(node.findAll(text=True)))

url = ("https://www.prothomalo.com/search/?q="+q)
r1 = requests.get(url)
soup1 = BeautifulSoup(r1.content, 'html.parser') 
#print(soup.prettify()) 

#soup = BeautifulSoup(txt, "html.parser")
#print("".join(soup.strings))
#url = urllib2.urlopen("https://www.python.org")

    
for node1 in soup1.find_all("img"):

    
    print (''.join(node1.findAll(text=True)))
# Out:
# Enter keyword here:অরিন্দম পাল
# অরিন্দম পাল Profiles | Facebook
# Arindom Pal Books: অরিন্দম পাল এর বই সমূহ | Rokomari.com
# অরিন্দম পাল | Techtunes | টেকটিউনস
# অরিন্দম পাল রিপন - এর বাংলা ব্লগ । bangla blog | সামহোয়্যার ইন ব্লগ ...
# অরিন্দম পাল-এর ছবি
# অরিন্দম পাল | blog.bdnews24.com - pioneer blog for citizen ...
# অরিন্দম পাল | about.me
# অরিন্দম পাল | Free Listening on SoundCloud
# অরিন্দম পাল « প্রতিলিপি বাংলা | Arindam Paul « Pratilipi Bengali
# Algebra Problem: Someone loves Mathematics and A Girl..... - Brilliant
#
# প্রচ্ছদ
# আবাসন মেলা
# বাংলাদেশ
# আন্তর্জাতিক
# অর্থনীতি
# মতামত
# খেলা
# বিনোদন
# কার্টুন
# ফিচার
# বিজ্ঞান ও প্রযুক্তি
# জীবনযাপন
# শিক্ষা
# শিল্প ও সাহিত্য
# আমরা
# পাঁচমিশালি
# বিশেষ সংখ্যা
# উত্তর আমেরিকা
# ইপেপার
# ছবি
# ভিডিও
# আর্কাইভ
# বিজ্ঞাপন
# সার্কুলেশন
# পবিত্র হজ
# দূর পরবাস
# উত্তর আমেরিকা
# ২২২২১
# ট্রাস্ট
# প্রতিচিন্তা
# কিশোর আলো
# abc রেডিও
#
# English
# লগইন
# রেজিস্টার
# Facebook
# Twitter
# Pinterest
# Google Plus
# YouTube
# ...

# %%
import requests 
import re
from bs4 import BeautifulSoup 
q = input("Enter keyword here:")
url1 = ("https://www.google.com.bd/search?hl=en&tbm=isch&source=hp&biw=1280&bih=581&ei=yupKXLHmA9X0rQGV64ugBQ&q="+q)
r2 = requests.get(url1)
#soup2 = BeautifulSoup(r2.content, 'html.parser') 
soup2 = (r2.content, "html.parser")
# Out:
# Enter keyword here:arindam kumar paul

# %%
print(soup2.prettify())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-b1615fa07097> in <module>()
# ----> 1 print(soup2.prettify())
#
# AttributeError: 'tuple' object has no attribute 'prettify'

# %%
import requests 
import re
from bs4 import BeautifulSoup 
q = input("Enter keyword here:")
URL = ("https://www.google.com/search?q="+q)

r = requests.get(URL) 

#soup = BeautifulSoup(r.content)
soup = BeautifulSoup(r.content, 'html.parser') 
#print(soup.prettify()) 

#soup = BeautifulSoup(txt, "html.parser")
#print("".join(soup.strings))
#url = urllib2.urlopen("https://www.python.org")

    
for node in soup.findAll('h3'):
    print (''.join(node.findAll(text=True)))

url = ("https://www.prothomalo.com/search/?q="+q)
r1 = requests.get(url)
soup1 = BeautifulSoup(r1.content, 'html.parser') 
print(soup1.prettify()) 

#soup = BeautifulSoup(txt, "html.parser")
#print("".join(soup.strings))
#url = urllib2.urlopen("https://www.python.org")

print("Bing : ")   
for node in soup1.find_all("a"):

    
    print (''.join(node.findAll(text=True)))
# Out:
# Enter keyword here:arindam kumar paul
# Arindam Kumar Paul | Khulna University, Khulna | KU | Department ...
# Arindam Kumar Paul - Google Scholar Citations
# ব্যবহারকারী:Arindam Kumar Paul - বাংলা উইকিপিডিয়া
# A Highly Secured Mathematical Model for Data Encryption Using ...
# Khulna University | IEOM
# arindam kumar paul-এর ছবি
# Arindam Kumar Paul - Senior Associate - Cognizant | LinkedIn
# Arindam Kumar Paul, SAFe-SP, ISTQB certified. - QA Lead and ...
# An Approach to Increase Motorcycle Safety by Analyzing Some ...
# Arindam Paul | Facebook
# <!DOCTYPE doctype html>
# <html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="bn">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <noscript>
#    <meta content="0;url=/search?q=arindam+kumar+paul&amp;ie=UTF-8&amp;gbv=1&amp;sei=RuFKXIeeMMLIyAPgh5_4AQ" http-equiv="refresh"/>
# ...

# %%
print("Bing : ")   
for node in soup1.find_all("a"):

    
    print (''.join(node.findAll(text=True)))
# Out:
# Bing :
#
# প্রচ্ছদ
# আবাসন মেলা
# বাংলাদেশ
# আন্তর্জাতিক
# অর্থনীতি
# মতামত
# খেলা
# বিনোদন
# কার্টুন
# ফিচার
# বিজ্ঞান ও প্রযুক্তি
# জীবনযাপন
# শিক্ষা
# শিল্প ও সাহিত্য
# আমরা
# পাঁচমিশালি
# বিশেষ সংখ্যা
# উত্তর আমেরিকা
# ইপেপার
# ছবি
# ভিডিও
# আর্কাইভ
# বিজ্ঞাপন
# সার্কুলেশন
# পবিত্র হজ
# দূর পরবাস
# উত্তর আমেরিকা
# ২২২২১
# ট্রাস্ট
# প্রতিচিন্তা
# কিশোর আলো
# abc রেডিও
#
# English
# লগইন
# রেজিস্টার
# Facebook
# Twitter
# Pinterest
# Google Plus
# YouTube
# Instagram
# আবাসন মেলা
# বাংলাদেশ
# আন্তর্জাতিক
# অর্থনীতি
# মতামত
# খেলা
# বিনোদন
# ছবি
# ভিডিও
# ইপেপার
# উত্তর আমেরিকা
# জীবনযাপন
#
# অনুসন্ধান
#
# প্রচ্ছদ
# অনুসন্ধান
#
#  কলকাতা বইমেলায় যোগ দিচ্ছে বাংলাদেশের ৪১টি প্রকাশনা সংস্থা
#
#
#  শেষ ওভারে এ কোন মোস্তাফিজ!
#
#
#  কুকুরের গায়ে দামি জ্যাকেট!
#
#
#  জাতীয় জরুরি অবস্থা ঘোষণার খসড়া করছে হোয়াইট হাউস
#
#
#  ‘কবির সিং’ ছবির সেটে মৃত্যু
#
# সব শেষ
#
#  ইস্টার্ন ইউনিভার্সিটি বন্ধুসভার কম্বল বিতরণ
#
#
#  এ কেমন মাঘ মাস!
#
#
# ...

# %%
from bs4 import BeautifulSoup
import urllib
from urllib import request
import re
import re
import string 
import requests
import csv

def BdMobileNumbers(text):
    if len(text) != 11:
        return False
    for i in range(0, 3):
        if not text[i].isdecimal():
            return False
    if text[0] != "0":
        return False
    if text[1] != '1':
        return False
    for i in range(0, 10):
        if text[i].isspace():
            return False
    for i in range(0, 5):
        if not text[i].isdigit():
            return False
    return True

link = input("Enter The Link To Find All Mobile Numbers  : ")

    

h = requests.get(link)
data = h.text
names = []
with open('C:/Users/AP/Desktop/New folder/a.txt', 'w+', encoding='utf-8') as myfile:
    for i in range(len(data)):
   
        l = data[i:i+11]
        if BdMobileNumbers(l):
        
            myfile.write( l )
            myfile.write('\n')
        
        
        #print(l)
            

        
        
            
            
print('Done')
# Out:
# Enter The Link To Find All Mobile Numbers  : http://ideabank.eservice.gov.bd/
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ...
